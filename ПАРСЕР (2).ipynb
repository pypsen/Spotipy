# %% [markdown]
# ## Необходимые пакеты:

# %%
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
import chromedriver_binary 
import urllib
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import lxml
import requests
import base64
import json
import pandas as pd
import numpy as np
from secrets import *
import urllib.request
from fake_useragent import UserAgent
from bs4 import BeautifulSoup 
from selenium.webdriver.common.action_chains  import ActionChains
import random

# %% [markdown]
# #####  Подготовка к работе с API, авторизируемся на сайте и изменяем кодировку для получения токена доступа.

# %%
url = "https://accounts.spotify.com/api/token"
headers = {}
data = {}


message = f"{'3e661d7345d04909b518ec04ec996fd2'}:{'c3ce130028654a779d6404a619845bd6'}"
messageBytes = message.encode('ascii')
base64Bytes = base64.b64encode(messageBytes)
base64Message = base64Bytes.decode('ascii')

headers['Authorization'] = f"Basic {base64Message}"
data['grant_type'] = "client_credentials"

r = requests.post(url, headers=headers, data=data)

token = r.json()['access_token']

# %%
token
# Out:
# 'BQC6jImb6Kgk-_GieV-71VsqWkkGumXqwYwbRZFiNK-BtLRe8Ywqigr7QwMojEMDcMfmzHcgwFD3AzPBFY8'

# %% [markdown]
# Успешно получен токен.

# %% [markdown]
# ###### Функция получения сведений о треках, находящихся в одном плейлисте

# %%
def get_playlist(playlist_id):
    playlistUrl = f'https://api.spotify.com/v1/playlists/{playlist_id}/tracks'
    headers = {
        "Authorization": "Bearer " + token
    }
    
    page = requests.get(url=playlistUrl, headers=headers)
    page =  page.json()
    page = playlist_req_to_list (page)    
    return page

# %% [markdown]
# ###### Функция по вытягиванию параметров песни

# %%
def song_paramets(song_id):
    
    song_url = f'https://api.spotify.com/v1/audio-features/{song_id}'
    headers = {
        "Authorization": "Bearer " + token
    }

    page = requests.get(url=song_url, headers=headers)
    page =  page.json()
    return page

# %% [markdown]
# ###### Функция распредения инфомации из json-формата в DataFrame-таблицу

# %%
def playlist_req_to_list(file):

    song_name = [None for i in range(50)]
    song_id = [None for i in range(50)]
    duration = [None for i in range(50)]
    artist_name = [None for i in range(50)]
    artist_id = [None for i in range(50)]
    album_name = [None for i in range(50)]
    album_id = [None for i in range(50)]
    release_date = [None for i in range(50)]
    local_position = [None for i in range(50)]
    world_position = [None for i in range(50)]
    danceability = [None for i in range(50)]
    energy = [None for i in range(50)]
    key = [None for i in range(50)]
    loudness = [None for i in range(50)]
    mode = [None for i in range(50)]
    speechiness = [None for i in range(50)]
    acousticness = [None for i in range(50)]
    instrumentalness = [None for i in range(50)]
    liveness = [None for i in range(50)]
    valence = [None for i in range(50)]
    tempo = [None for i in range(50)]
      
    i = 0
    
    for item in file['items']:        
        song_name[i] = item['track']['name']
        song_id[i] = item['track']['id']
        duration[i] = item['track']['duration_ms']
        local_position[i] = item['track']['popularity']       
        artist_name[i] = item['track']['album']['artists'][0]['name']
        artist_id[i] = item['track']['album']['artists'][0]['id']
        album_name[i] = item['track']['album']['name']
        album_id[i] = item['track']['album']['id']
        release_date[i] = item['track']['album']['release_date']
        
        parametrs = song_paramets(song_id[i])
        
        danceability[i] = parametrs['danceability']
        energy[i] = parametrs['energy']
        key[i] = parametrs['key']
        loudness[i] = parametrs['loudness']
        mode[i] = parametrs['mode']
        speechiness[i] = parametrs['speechiness']
        acousticness[i] = parametrs['acousticness']
        instrumentalness[i] = parametrs['instrumentalness']
        liveness[i] = parametrs['liveness']
        valence[i] = parametrs['valence']
        tempo[i] = parametrs['tempo']
        
        i += 1
        
    data_dict = {'song_name' : song_name,
                 'song_id' : song_id,
                 'duration_ms' : duration,
                 'local_position' : local_position,
                 'artist_name' : artist_name,
                 'artist_id' : artist_id,
                 'album_name' : album_name,
                 'album_id' : album_id,
                 'release_date' : release_date,
                 'danceability': danceability,
                 'energy': energy,
                 'key': key,
                 'loudness': loudness,
                 'mode': mode,
                 'speechiness': speechiness,
                 'acousticness': acousticness,
                 'instrumentalness': instrumentalness,
                 'liveness': liveness,
                 'valence': valence,
                 'tempo': tempo
                }
    data_set = pd.DataFrame(data_dict)
    
    return data_set

# %% [markdown]
# ##### Функция по получению основной инфы о плейлисте

# %%
def playlist_info(playlist_id):
    playlistUrl = f'https://api.spotify.com/v1/playlists/{playlist_id}'
    headers = {
        "Authorization": "Bearer " + token
    }
    
    page = requests.get(url=playlistUrl, headers=headers)
    page =  page.json()
    text = page['description']
    number = page['followers']['total']
    country = text[text.find('now -')+6:-1]
    info = [country,number]
    return info

# %% [markdown]
# ## Находим все айдишники альбомов
# #### Полученное ids-список айдишников

# %%
site = "https://open.spotify.com/genre/charts-regional-weekly"

#chrome_options = Options() работает у Дениса
#chrome_options.add_argument("--headless")   настройка на всякий случай

#настраиваем селениум
driver = webdriver.Chrome('D:\chromedriver.exe') #работает у Дениса
#driver = webdriver.Chrome('/Users/alexandr/Downloads/chromedriver') #работает у Сани
#открываем сайт, двигаем мышку и кликаем, чтобы потом заработала прокрутка
driver.get(site)

driver.maximize_window()
time.sleep(3)
ActionChains(driver).move_by_offset(1520, 350).click().perform() #у дениса 1520 350 у саши 2000 900
time.sleep(3)
driver.find_element_by_xpath('//body').send_keys(Keys.END) 
time.sleep(3)
driver.find_element_by_xpath('//body').send_keys(Keys.END) #моя добавка
time.sleep(3)


#получаем код страницы и делаем суп
response = driver.page_source
driver.close()
tree = BeautifulSoup(response, 'html.parser')

# %%
#ищем все ссылки на странице
a = tree.find_all('a', class_ = 'f7ebc3d96230ee12a84a9b0b4b81bb8f-scss')

#из блоков с ссылками достаем айдишники
ids = []
for i in a:
    id = i.get('href')
    ids.append(id[10:])

# %% [markdown]
# ##### Функция по поиску прослушиваний для каждого плейлиста

# %%
def viewslist(playlist_id):
    site = f'https://open.spotify.com/playlist/{playlist_id}'
    driver = webdriver.Chrome('/Users/alexandr/Downloads/chromedriver')
    driver.get(site)
    time.sleep(2)
    response = driver.page_source
    driver.close()
    tree = BeautifulSoup(response, 'html.parser')
    a = tree.find_all('div', class_ = 'd47b790d001ed769adcd9ddfc0e83acc-scss f3fc214b257ae2f1d43d4c594a94497f-scss')
    res = []
    b = list(a)
    for i in b:
        views = str(i)[-16:-6].replace('\xa0', '')
        res.append(views)
    views = []
    for i in res:
        ddd = [s for s in i.split('>') if s.isdigit()]
        views.append(int(ddd[0]))
    return views

# %% [markdown]
# #### функция для получения жанров для каждого исполнителя в топе

# %%
#playlist - таблица, которую выдает функция get_playlist
def get_genres(playlist):
    artists = list(a["artist_id"])
    result = []
    for i in tqdm(artists):
        id = i
        playlistUrl = f'https://api.spotify.com/v1/artists/{id}'
        headers = {"Authorization": "Bearer " + token}
        page = requests.get(url=playlistUrl, headers=headers)
        page = page.json()
        genres = page['genres']
        result.append(genres)
        time.sleep(0.5)
    return result

# %% [markdown]
# # ЭЭЭэээээксерименты

# %%
playlist_id = '37i9dQZEVXbL1Fl8vdBUba'
playlist = get_playlist(playlist_id)

# %%
def get_MainInfo(playlist, playlist_id):
    #создаем часть таблицы (место в топе в качестве индекса, имена и id песен)
    MainInfo = playlist[['song_name', 'song_id']]
    
    #парсим код страницы альбома с испльзованием селениума
    site = "https://open.spotify.com/playlist/" + playlist_id
    chrome_options = Options()
    driver = webdriver.Chrome(options=chrome_options)
    driver.get(site)
    time.sleep(2)
    response = driver.page_source
    driver.close()
    tree = BeautifulSoup(response, 'html.parser')
    
    #ищем все куски кода, где написаны просмотры
    a = tree.find_all('div', class_ = 'd47b790d001ed769adcd9ddfc0e83acc-scss f3fc214b257ae2f1d43d4c594a94497f-scss')
    
    #из них получаем строки с прослушиваниями и обрабатываем их
    res = []
    b = list(a)
    for i in b:
        views = str(i)[-16:-6].replace('\xa0', '')
        res.append(views)
    #res - список прослушиваний от топа ко дну (неформатированный)
    #вытащим из элементов res только числа
    views = []
    for i in res:
        ddd = [s for s in i.split('>') if s.isdigit()]
        views.append(int(ddd[0]))
    #views - просмотры по порядку для каждой песни из топа
    #добавляем колонки с просмотрами, местом в топе и страной к существующей таблице
    MainInfo.insert(2, "views", views)
    MainInfo.insert(0, "place", range(1,51))
    MainInfo.insert(0, "country", playlist_info(playlist_id)[0])
    return MainInfo

# %%
sss = get_MainInfo(playlist, playlist_id)
sss
# Out:
#      country  place                               song_name  \
# 0   Colombia      1                                      Am
# 1   Colombia      2                                 Poblado
# 2   Colombia      3                                    Fiel
# 3   Colombia      4                          Pareja Del Año
# 4   Colombia      5                              EL MAKINON
# 5   Colombia      6                                  Butter
# 6   Colombia      7                               2/Catorce
# 7   Colombia      8                              Todo De Ti
# 8   Colombia      9                                 Bandido
# 9   Colombia     10                                  DÁKITI
# 10  Colombia     11                    Botella Tras Botella
# 11  Colombia     12                                     911
# 12  Colombia     13                      LA NOCHE DE ANOCHE
# 13  Colombia     14                                good 4 u
# 14  Colombia     15                                   Reloj
# 15  Colombia     16                            Sal y Perrea
# 16  Colombia     17                                CHIMBITA
# 17  Colombia     18                       IMPOSIBLE - REMIX
# 18  Colombia     19                                 La Nota
# 19  Colombia     20                              Una Locura
# 20  Colombia     21                                   Aloha
# 21  Colombia     22  Peaches (feat. Daniel Caesar & Giveon)
# 22  Colombia     23                            Hecha Pa' Mi
# 23  Colombia     24          MONTERO (Call Me By Your Name)
# 24  Colombia     25                               telepatía
# 25  Colombia     26                             Hasta Abajo
# 26  Colombia     27                Kiss Me More (feat. SZA)
# 27  Colombia     28                                   Hawái
# 28  Colombia     29                               Explícito
# 29  Colombia     30                             Alguien Más
# 30  Colombia     31                 Ella No Es Tuya - Remix
# 31  Colombia     32                                 BICHOTA
# 32  Colombia     33                                     512
# 33  Colombia     34                                Dynamite
# 34  Colombia     35                                 Mi Niña
# 35  Colombia     36                                EL BARCO
# 36  Colombia     37                             PURRITO APA
# 37  Colombia     38               Levitating (feat. DaBaby)
# 38  Colombia     39                           La Curiosidad
# 39  Colombia     40                                 deja vu
# 40  Colombia     41                               Tu Veneno
# 41  Colombia     42                              TE MUDASTE
# 42  Colombia     43     Baila Conmigo (with Rauw Alejandro)
# 43  Colombia     44                         drivers license
# 44  Colombia     45                         Blinding Lights
# 45  Colombia     46          UN DIA (ONE DAY) (Feat. Tainy)
# 46  Colombia     47             Parce (feat. Justin Quiles)
# 47  Colombia     48                                LOCATION
# 48  Colombia     49                  No Te Enamores - Remix
# 49  Colombia     50                            Amor en Coma
#
#                    song_id   views
# 0   2dNhNlpZAtV4lwAFW45LIv  814251
# 1   7xT1n5JKpB0bMPh6FL589e  776188
# 2   7Bk0uXKk1uPT0XuQbpFzvs  766470
# 3   2rCbl9naJYhaxjLsfx88uM  716900
# 4   2FSGUA0gFgGeQdprjtGM2M  623622
# 5   3VqeTFIvhxu3DIe4eZVzGq  595085
# 6   71R8HJxQk5qMiRstrlXN9t  579214
# 7   4fSIb4hdOQ151TILNsSEaF  530732
# 8   1xK1Gg9SxG8fy2Ya373oqb  496087
# 9   4MzXwWMhyBbmu6hOcLVD49  494542
# 10  2MnLkFqY9Rpg9s3Zv6ZJdK  472170
# 11  2p2Q23iaaPSEa1tI6TsCVX  442434
# 12  2XIc1pqjXV3Cr2BQUGNBck  415220
# 13  4ZtFanR9U6ndgddUvNcjcG  368015
# 14  4loQgPwJHocL3dFwLfjb1J  361175
# 15  5u7twkeask1VIyDeNTElSU  342163
# 16  5xwjEzvJ2OSdnHlzusKNYA  333469
# 17  5eaLGyPrVG7FbZ5vVnBm93  332453
# 18  5VzNsUnLmYcRfRfxpQsusa  322889
# 19  5y7DaS3jAc9eZzcSOoUIwU  313332
# 20  5RAIMjdrCEjpjaR5tBATXU  312289
# 21  4iJyoBOLtHqaGxP12qzhQI  307426
# 22  3VvA1wSxukMLsvXoXtlwWx  306199
# 23  67BtfxlNbhBmCDR2L2l8qd  304486
# 24  6tDDoYIxWvMLTdKpjFkc1B  291189
# 25  4PEfJZpVjdclfzZ9XO8uDw  289710
# 26  748mdHapucXQri7IAO8yFK  282587
# 27  1yoMvmasuxZfqHEipJhRbp  277785
# 28  6qraVL4IJaIj0IuEexYJNa  272671
# 29  5mROvpdGeu1vSbZhZoay5O  267763
# 30  5YYW3yRktprLRr47WK219Y  266544
# 31  1WvrDdouh6C51In1SdATbq  255188
# 32  5jzEwSyyymBlf1fa1o39T2  249081
# 33  4saklk6nie3yiGePpBwUoc  247509
# 34  2bgcUk2A3jjKbCJ7KPquTi  247043
# 35  0MT6qJd7wKlWjH7tP7oWHi  241389
# 36  4e54PAuILqrhjr2ryuMvdq  239229
# 37  5nujrmhLynf4yMoMtj8AQF  236265
# 38  4HYDUMY0xSpeBr0AMY9cUz  234698
# 39  6HU7h9RYOaPRFeh0R3UeAr  233627
# 40  5KFHrrBMyGj5MhVbZMM3ts  232059
# 41  5RubKOuDoPn5Kj5TLVxSxY  231906
# 42  079Ey5uxL04AKPQgVQwx5h  230416
# 43  5wANPM4fQCJwkGd4rN57mH  223256
# 44  0VjIjW4GlUZAMYd2vXMi3b  220951
# 45  0EhpEsp4L0oRGM0vmeaN5e  218281
# 46  4RJz8NfIe09gpKMiRUWKhJ  217974
# 47  478g4LSkyMB1PMkVOVmIaE  217304
# 48  2mM3gZ0BbPwPPMelbA8vgt  216854
# 49  0kRU83ecI57Iw1kPTeUwK5  212617

# %%
list(sss['song_name'])
# Out:
# ['Am',
#  'Poblado',
#  'Fiel',
#  'Pareja Del Año',
#  'EL MAKINON',
#  'Butter',
#  '2/Catorce',
#  'Todo De Ti',
#  'Bandido',
#  'DÁKITI',
#  'Botella Tras Botella',
#  '911',
#  'LA NOCHE DE ANOCHE',
#  'good 4 u',
#  'Reloj',
#  'Sal y Perrea',
#  'CHIMBITA',
#  'IMPOSIBLE - REMIX',
#  'La Nota',
#  'Una Locura',
#  'Aloha',
#  'Peaches (feat. Daniel Caesar & Giveon)',
#  "Hecha Pa' Mi",
#  'MONTERO (Call Me By Your Name)',
#  'telepatía',
#  'Hasta Abajo',
#  'Kiss Me More (feat. SZA)',
#  'Hawái',
#  'Explícito',
#  'Alguien Más',
#  'Ella No Es Tuya - Remix',
#  'BICHOTA',
#  '512',
#  'Dynamite',
#  'Mi Niña',
#  'EL BARCO',
#  'PURRITO APA',
#  'Levitating (feat. DaBaby)',
#  'La Curiosidad',
#  'deja vu',
#  'Tu Veneno',
#  'TE MUDASTE',
#  'Baila Conmigo (with Rauw Alejandro)',
#  'drivers license',
#  'Blinding Lights',
#  'UN DIA (ONE DAY) (Feat. Tainy)',
#  'Parce (feat. Justin Quiles)',
#  'LOCATION',
#  'No Te Enamores - Remix',
#  'Amor en Coma']

# %% [markdown]
# # Cобираем датасэты

# %% [markdown]
# ## Структура данных:
# #### Маленький датасетик вида (айди листа, страна, кол-во лайков)
# #### Датасет побольбше (данные о каждой песне)
# #### Датасет совсем большой че с ним (данные о позиции и прослушиваниях каждой песни в каждом топе)

# %% [markdown]
# ### Маленький датасетик
